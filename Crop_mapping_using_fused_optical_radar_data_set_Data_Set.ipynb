# %% [markdown]
# # **Basic EDA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# %cd '/content/gdrive/My Drive/Data_Set/'
# Out:
# /content/gdrive/My Drive/Data_Set

# %%
data = pd.read_csv('WinnipegDataset.txt')
data
# Out:
#         label        f1       f2        f3  ...     f171     f172     f173     f174
# 0           1 -13.55900 -21.4070 -11.40400  ...  2.44440  1.67700  0.20988  0.65422
# 1           1 -12.80200 -20.3350 -10.39900  ...  0.33333  0.84869  0.50617 -0.18898
# 2           1 -12.43100 -19.9020 -10.07400  ...  0.66667  1.27300  0.30864  0.10483
# 3           1 -12.68900 -19.5290 -10.02800  ...  0.33333  1.14910  0.38272  0.41603
# 4           1 -12.68600 -19.2780  -9.81850  ...  0.66667  1.58110  0.20988  0.50000
# ...       ...       ...      ...       ...  ...      ...      ...      ...      ...
# 325829      7   2.48230  -7.6870   1.07950  ...  0.22222  1.06090  0.35802  0.63246
# 325830      7   2.52340  -7.6745   1.08680  ...  4.00000  2.19720  0.11111  0.81224
# 325831      7  -1.92700 -11.4160  -2.43540  ...  0.33333  1.27300  0.30864  0.31623
# 325832      7   0.12483 -10.1440  -0.62193  ...  0.11111  0.34883  0.80247  0.18898
# ...

# %% [markdown]
# # **Other functions**

# %%
# Renaming the column names
data = data.rename(columns= {'label':'Crop_type'})

# %%
data.head(5)  # to check the top n records as .head(n)
# Out:
#    Crop_type      f1      f2       f3  ...     f171     f172     f173     f174
# 0          1 -13.559 -21.407 -11.4040  ...  2.44440  1.67700  0.20988  0.65422
# 1          1 -12.802 -20.335 -10.3990  ...  0.33333  0.84869  0.50617 -0.18898
# 2          1 -12.431 -19.902 -10.0740  ...  0.66667  1.27300  0.30864  0.10483
# 3          1 -12.689 -19.529 -10.0280  ...  0.33333  1.14910  0.38272  0.41603
# 4          1 -12.686 -19.278  -9.8185  ...  0.66667  1.58110  0.20988  0.50000
#
# [5 rows x 175 columns]

# %%
data.tail(10)   # to check the bottom n records as .head(n)  
# This is a continuous data f1-f174
# label is a discrete data
# Alogrithm to be identified.
# Out:
#         Crop_type       f1       f2  ...     f172     f173     f174
# 325824          7  1.74470  -8.6089  ...  1.42710  0.28395  0.10483
# 325825          7 -0.14863  -9.4782  ...  0.68696  0.50617  0.18898
# 325826          7  2.50340  -7.5891  ...  1.42710  0.28395  0.60083
# 325827          7  2.53560  -7.6144  ...  2.04320  0.13580  0.72019
# 325828          7 -0.20969  -9.6902  ...  0.93689  0.43210  0.39528
# 325829          7  2.48230  -7.6870  ...  1.06090  0.35802  0.63246
# 325830          7  2.52340  -7.6745  ...  2.19720  0.11111  0.81224
# 325831          7 -1.92700 -11.4160  ...  1.27300  0.30864  0.31623
# 325832          7  0.12483 -10.1440  ...  0.34883  0.80247  0.18898
# 325833          7  0.20063 -10.0500  ...  2.04320  0.13580  0.72732
#
# [10 rows x 175 columns]

# %%
# Checking the datatype
data.dtypes  # tell what is the datatype of each column
# Out:
# Crop_type      int64
# f1           float64
# f2           float64
# f3           float64
# f4           float64
#               ...
# f170         float64
# f171         float64
# f172         float64
# f173         float64
# f174         float64
# Length: 175, dtype: object

# %%
# Total number of rows and columns
data.shape
# Out:
# (325834, 175)

# %%
data.info()  # to know more information about your dataset   also tells if there are null values or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325834 entries, 0 to 325833
# Columns: 175 entries, Crop_type to f174
# dtypes: float64(169), int64(6)
# memory usage: 435.0 MB

# %%
data.describe()  # Statistics
# Out:
#            Crop_type             f1  ...           f173           f174
# count  325834.000000  325834.000000  ...  325834.000000  325834.000000
# mean        4.062421     -15.143602  ...       0.764646       0.667567
# std         1.604617       3.504255  ...       0.273847       0.471260
# min         1.000000     -23.971000  ...       0.111110      -1.000000
# 25%         3.000000     -17.848000  ...       0.506170       0.357140
# 50%         4.000000     -15.992000  ...       1.000000       1.000000
# 75%         6.000000     -11.786000  ...       1.000000       1.000000
# max         7.000000       2.535600  ...       1.000000       1.000000
#
# [8 rows x 175 columns]

# %%
# To check if data contains null values
data.isnull().values.any()
# Out:
# False

# %%
# Finding the null values
print(data.isnull().sum)
# Out:
# <bound method DataFrame.sum of         Crop_type     f1     f2     f3  ...   f171   f172   f173   f174
# 0           False  False  False  False  ...  False  False  False  False
# 1           False  False  False  False  ...  False  False  False  False
# 2           False  False  False  False  ...  False  False  False  False
# 3           False  False  False  False  ...  False  False  False  False
# 4           False  False  False  False  ...  False  False  False  False
# ...           ...    ...    ...    ...  ...    ...    ...    ...    ...
# 325829      False  False  False  False  ...  False  False  False  False
# 325830      False  False  False  False  ...  False  False  False  False
# 325831      False  False  False  False  ...  False  False  False  False
# 325832      False  False  False  False  ...  False  False  False  False
# 325833      False  False  False  False  ...  False  False  False  False
#
# [325834 rows x 175 columns]>

# %%
# After dropping the values
print(data.isnull().sum)
# Out:
# <bound method DataFrame.sum of         Crop_type     f1     f2     f3  ...   f171   f172   f173   f174
# 0           False  False  False  False  ...  False  False  False  False
# 1           False  False  False  False  ...  False  False  False  False
# 2           False  False  False  False  ...  False  False  False  False
# 3           False  False  False  False  ...  False  False  False  False
# 4           False  False  False  False  ...  False  False  False  False
# ...           ...    ...    ...    ...  ...    ...    ...    ...    ...
# 325829      False  False  False  False  ...  False  False  False  False
# 325830      False  False  False  False  ...  False  False  False  False
# 325831      False  False  False  False  ...  False  False  False  False
# 325832      False  False  False  False  ...  False  False  False  False
# 325833      False  False  False  False  ...  False  False  False  False
#
# [325834 rows x 175 columns]>

# %%
import seaborn as sns
corr = data.corr()
sns.heatmap(corr,annot=True)
# It tries to check relationship between two different attributes
# heatmap -- trying to find correlation between the data then plot

# %%
data['f1'].value_counts()  # to find the count of values in a particular column
# Out:
# -16.3680    75
# -16.0870    73
# -16.3540    72
# -17.7390    71
# -16.1260    70
#             ..
# -9.6905      1
# -8.5466      1
# -9.1546      1
# -8.4886      1
# -9.0145      1
# Name: f1, Length: 27452, dtype: int64

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 325829    False
# 325830    False
# 325831    False
# 325832    False
# 325833    False
# Length: 325834, dtype: bool

# %%
data.isnull().sum()
# Out:
# Crop_type    0
# f1           0
# f2           0
# f3           0
# f4           0
#             ..
# f170         0
# f171         0
# f172         0
# f173         0
# f174         0
# Length: 175, dtype: int64

# %% [markdown]
# # **Feature Engineering**

# %%
data.corr()
# Out:
#            Crop_type        f1        f2  ...      f172      f173      f174
# Crop_type   1.000000 -0.644986 -0.644821  ...  0.058235 -0.061464 -0.052463
# f1         -0.644986  1.000000  0.959623  ... -0.022247  0.024887  0.018481
# f2         -0.644821  0.959623  1.000000  ... -0.010552  0.013447  0.010665
# f3         -0.748987  0.878904  0.871976  ... -0.028708  0.032470  0.024714
# f4         -0.726806  0.940764  0.939766  ... -0.024264  0.027487  0.021900
# ...              ...       ...       ...  ...       ...       ...       ...
# f170        0.038036  0.011096  0.019581  ...  0.609302 -0.591693 -0.463072
# f171        0.050327 -0.009695  0.001523  ...  0.898733 -0.897437 -0.759399
# f172        0.058235 -0.022247 -0.010552  ...  1.000000 -0.993672 -0.766471
# f173       -0.061464  0.024887  0.013447  ... -0.993672  1.000000  0.776471
# f174       -0.052463  0.018481  0.010665  ... -0.766471  0.776471  1.000000
#
# [175 rows x 175 columns]

# %% [markdown]
# # **Statistics Functions**

# %%
data.count()  # prints the no. of values except NaN values in a column
# Out:
# Crop_type    325834
# f1           325834
# f2           325834
# f3           325834
# f4           325834
#               ...
# f170         325834
# f171         325834
# f172         325834
# f173         325834
# f174         325834
# Length: 175, dtype: int64

# %%
data.count(axis=1)  # prints the no. of values except NaN values in a row
# Out:
# 0         175
# 1         175
# 2         175
# 3         175
# 4         175
#          ...
# 325829    175
# 325830    175
# 325831    175
# 325832    175
# 325833    175
# Length: 325834, dtype: int64

# %%
data.min()  # to find minimum values in each column
# Out:
# Crop_type     1.00000
# f1          -23.97100
# f2          -34.30800
# f3          -23.16100
# f4          -27.24500
#                ...
# f170          0.00000
# f171          0.00000
# f172         -0.00000
# f173          0.11111
# f174         -1.00000
# Length: 175, dtype: float64

# %%
data.min(axis=1)  # to find minimum values in each row
# Out:
# 0        -23.436
# 1        -22.730
# 2        -22.566
# 3        -22.520
# 4        -22.387
#            ...
# 325829   -17.106
# 325830   -17.211
# 325831   -18.389
# 325832   -17.739
# 325833   -17.479
# Length: 325834, dtype: float64

# %%
data.max()   # to find maximum values in each column
# Out:
# Crop_type     7.00000
# f1            2.53560
# f2           -7.58910
# f3            1.10400
# f4            0.77491
#                ...
# f170         66.66700
# f171          6.66670
# f172          2.19720
# f173          1.00000
# f174          1.00000
# Length: 175, dtype: float64

# %%
data.max(axis=1)   # to find maximum values in each row
# Out:
# 0         294110.0
# 1         412400.0
# 2         439570.0
# 3         296240.0
# 4         232610.0
#             ...
# 325829    423430.0
# 325830    222500.0
# 325831    354320.0
# 325832    216430.0
# 325833    150320.0
# Length: 325834, dtype: float64

# %%
np.argmin(data)   # this is a numpy function which is used in pandas to find the index with minimum value
# Out:
# 56839107

# %%
np.argmax(data)  # this is a numpy function which is used in pandas to find the index with maximum value
# Out:
# 7138054

# %%
data.idxmin()   # to print the index with minimum values
# Out:
# Crop_type         0
# f1           137478
# f2           153339
# f3           247451
# f4           155851
#               ...
# f170             10
# f171             10
# f172             10
# f173           4730
# f174          20605
# Length: 175, dtype: int64

# %%
data.idxmax()   # to print the index with maximum values
# Out:
# Crop_type    324691
# f1           325827
# f2           325826
# f3           325827
# f4           325827
#               ...
# f170         324786
# f171         324786
# f172           4730
# f173             10
# f174             10
# Length: 175, dtype: int64

# %%
data.quantile()    # to compute sample quantile ranging from 0 to 1
# Out:
# Crop_type     4.000
# f1          -15.992
# f2          -25.064
# f3          -16.164
# f4          -19.588
#               ...
# f170          0.000
# f171          0.000
# f172         -0.000
# f173          1.000
# f174          1.000
# Name: 0.5, Length: 175, dtype: float64

# %%
data.sum()  # to find sum of values in each column
# Out:
# Crop_type    1.323675e+06
# f1          -4.934300e+06
# f2          -7.828499e+06
# f3          -5.017855e+06
# f4          -6.058502e+06
#                  ...
# f170         5.684063e+04
# f171         5.307841e+04
# f172         1.314051e+05
# f173         2.491476e+05
# f174         2.175162e+05
# Length: 175, dtype: float64

# %%
data.mean()   # to find mean of values in each column
# Out:
# Crop_type     4.062421
# f1          -15.143602
# f2          -24.026035
# f3          -15.400034
# f4          -18.593830
#                ...
# f170          0.174447
# f171          0.162900
# f172          0.403288
# f173          0.764646
# f174          0.667567
# Length: 175, dtype: float64

# %%
data.median()    # to find median of values in each column
# Out:
# Crop_type     4.000
# f1          -15.992
# f2          -25.064
# f3          -16.164
# f4          -19.588
#               ...
# f170          0.000
# f171          0.000
# f172         -0.000
# f173          1.000
# f174          1.000
# Length: 175, dtype: float64

# %%
data.mad()   # to find mean absolute deviation of values in each column
# Out:
# Crop_type    1.303554
# f1           3.025937
# f2           3.489081
# f3           2.640778
# f4           3.152229
#                ...
# f170         0.195102
# f171         0.180713
# f172         0.427222
# f173         0.250414
# f174         0.407194
# Length: 175, dtype: float64

# %%
data.prod()   # to find product of values in each column
# Out:
# Crop_type    0.0
# f1          -inf
# f2           inf
# f3           inf
# f4           inf
#             ...
# f170         0.0
# f171         0.0
# f172         0.0
# f173         0.0
# f174        -0.0
# Length: 175, dtype: float64

# %%
data.var()  # to find variance of values in each column
# Out:
# Crop_type     2.574796
# f1           12.279800
# f2           16.436654
# f3           10.678888
# f4           13.776198
#                ...
# f170          0.139671
# f171          0.049288
# f172          0.230536
# f173          0.074992
# f174          0.222086
# Length: 175, dtype: float64

# %%
data.std()   # to find standard deviation of values in each column
# Out:
# Crop_type    1.604617
# f1           3.504255
# f2           4.054214
# f3           3.267857
# f4           3.711630
#                ...
# f170         0.373726
# f171         0.222008
# f172         0.480141
# f173         0.273847
# f174         0.471260
# Length: 175, dtype: float64

# %%
data.skew()   # to find skewness of values in each column
# Out:
# Crop_type    -0.416320
# f1            0.214773
# f2            0.261001
# f3            0.590859
# f4            0.458119
#                ...
# f170         44.876348
# f171          1.948235
# f172          0.720156
# f173         -0.572383
# f174         -1.084795
# Length: 175, dtype: float64

# %%
data.kurt()   # to find kurtosis of values in each column
# Out:
# Crop_type      -0.719310
# f1             -0.971268
# f2             -0.886081
# f3             -0.179401
# f4             -0.697562
#                 ...
# f170         6187.541686
# f171           11.693278
# f172           -0.913010
# f173           -1.330443
# f174           -0.236823
# Length: 175, dtype: float64

# %%
data.cumsum()   # to find cumulative sum of values in each column
# Out:
#         Crop_type            f1  ...          f173           f174
# 0               1 -1.355900e+01  ...       0.20988       0.654220
# 1               2 -2.636100e+01  ...       0.71605       0.465240
# 2               3 -3.879200e+01  ...       1.02469       0.570070
# 3               4 -5.148100e+01  ...       1.40741       0.986100
# 4               5 -6.416700e+01  ...       1.61729       1.486100
# ...           ...           ...  ...           ...            ...
# 325829    1323647 -4.934301e+06  ...  249146.28708  217514.115243
# 325830    1323654 -4.934299e+06  ...  249146.39819  217514.927483
# 325831    1323661 -4.934301e+06  ...  249146.70683  217515.243713
# 325832    1323668 -4.934301e+06  ...  249147.50930  217515.432693
# 325833    1323675 -4.934300e+06  ...  249147.64510  217516.160013
#
# [325834 rows x 175 columns]

# %%
data.cummin()   # to find cumulative minimum of values in each column
# Out:
#         Crop_type      f1      f2      f3  ...     f171     f172     f173     f174
# 0               1 -13.559 -21.407 -11.404  ...  2.44440  1.67700  0.20988  0.65422
# 1               1 -13.559 -21.407 -11.404  ...  0.33333  0.84869  0.20988 -0.18898
# 2               1 -13.559 -21.407 -11.404  ...  0.33333  0.84869  0.20988 -0.18898
# 3               1 -13.559 -21.407 -11.404  ...  0.33333  0.84869  0.20988 -0.18898
# 4               1 -13.559 -21.407 -11.404  ...  0.33333  0.84869  0.20988 -0.18898
# ...           ...     ...     ...     ...  ...      ...      ...      ...      ...
# 325829          1 -23.971 -34.308 -23.161  ...  0.00000 -0.00000  0.11111 -1.00000
# 325830          1 -23.971 -34.308 -23.161  ...  0.00000 -0.00000  0.11111 -1.00000
# 325831          1 -23.971 -34.308 -23.161  ...  0.00000 -0.00000  0.11111 -1.00000
# 325832          1 -23.971 -34.308 -23.161  ...  0.00000 -0.00000  0.11111 -1.00000
# ...

# %%
data.cummax()    # to find cumulative maximum of values in each column
# Out:
#         Crop_type       f1       f2       f3  ...    f171    f172     f173     f174
# 0               1 -13.5590 -21.4070 -11.4040  ...  2.4444  1.6770  0.20988  0.65422
# 1               1 -12.8020 -20.3350 -10.3990  ...  2.4444  1.6770  0.50617  0.65422
# 2               1 -12.4310 -19.9020 -10.0740  ...  2.4444  1.6770  0.50617  0.65422
# 3               1 -12.4310 -19.5290 -10.0280  ...  2.4444  1.6770  0.50617  0.65422
# 4               1 -12.4310 -19.2780  -9.8185  ...  2.4444  1.6770  0.50617  0.65422
# ...           ...      ...      ...      ...  ...     ...     ...      ...      ...
# 325829          7   2.5356  -7.5891   1.1040  ...  6.6667  2.1972  1.00000  1.00000
# 325830          7   2.5356  -7.5891   1.1040  ...  6.6667  2.1972  1.00000  1.00000
# 325831          7   2.5356  -7.5891   1.1040  ...  6.6667  2.1972  1.00000  1.00000
# 325832          7   2.5356  -7.5891   1.1040  ...  6.6667  2.1972  1.00000  1.00000
# ...

# %%
data.cumprod()    # to find cumulative product of values in each column
# Out:
#         Crop_type            f1            f2  ...      f172      f173      f174
# 0               1 -1.355900e+01 -2.140700e+01  ...  1.677000  0.209880  0.654220
# 1               1  1.735823e+02  4.353113e+02  ...  1.423253  0.106235 -0.123634
# 2               1 -2.157802e+03 -8.663566e+03  ...  1.811801  0.032788 -0.012961
# 3               1  2.738035e+04  1.691908e+05  ...  2.081941  0.012549 -0.005392
# 4               1 -3.473471e+05 -3.261660e+06  ...  3.291757  0.002634 -0.002696
# ...           ...           ...           ...  ...       ...       ...       ...
# 325829          0           inf           inf  ...  0.000000  0.000000 -0.000000
# 325830          0           inf          -inf  ...  0.000000  0.000000 -0.000000
# 325831          0          -inf           inf  ...  0.000000  0.000000 -0.000000
# 325832          0          -inf          -inf  ...  0.000000  0.000000 -0.000000
# 325833          0          -inf           inf  ...  0.000000  0.000000 -0.000000
#
# ...

# %%
data.diff()    # to find first arithmetic difference of values in each column
# Out:
#         Crop_type       f1      f2       f3  ...     f171     f172     f173     f174
# 0             NaN      NaN     NaN      NaN  ...      NaN      NaN      NaN      NaN
# 1             0.0  0.75700  1.0720  1.00500  ... -2.11107 -0.82831  0.29629 -0.84320
# 2             0.0  0.37100  0.4330  0.32500  ...  0.33334  0.42431 -0.19753  0.29381
# 3             0.0 -0.25800  0.3730  0.04600  ... -0.33334 -0.12390  0.07408  0.31120
# 4             0.0  0.00300  0.2510  0.20950  ...  0.33334  0.43200 -0.17284  0.08397
# ...           ...      ...     ...      ...  ...      ...      ...      ...      ...
# 325829        0.0  2.69199  2.0032  2.39520  ... -0.11111  0.12401 -0.07408  0.23718
# 325830        0.0  0.04110  0.0125  0.00730  ...  3.77778  1.13630 -0.24691  0.17978
# 325831        0.0 -4.45040 -3.7415 -3.52220  ... -3.66667 -0.92420  0.19753 -0.49601
# 325832        0.0  2.05183  1.2720  1.81347  ... -0.22222 -0.92417  0.49383 -0.12725
# ...

# %%
data.pct_change()   # to find percentge changes of values in each column
# Out:
#         Crop_type         f1        f2  ...      f172      f173      f174
# 0             NaN        NaN       NaN  ...       NaN       NaN       NaN
# 1             0.0  -0.055830 -0.050077  ... -0.493924  1.411711 -1.288863
# 2             0.0  -0.028980 -0.021293  ...  0.499959 -0.390244 -1.554715
# 3             0.0   0.020755 -0.018742  ... -0.097329  0.240021  2.968616
# 4             0.0  -0.000236 -0.012853  ...  0.375946 -0.451610  0.201836
# ...           ...        ...       ...  ...       ...       ...       ...
# 325829        0.0 -12.837951 -0.206724  ...  0.132363 -0.171442  0.600030
# 325830        0.0   0.016557 -0.001626  ...  1.071072 -0.689654  0.284255
# 325831        0.0  -1.763652  0.487524  ... -0.420626  1.777788 -0.610669
# 325832        0.0  -1.064779 -0.111423  ... -0.725978  1.600019 -0.402397
# 325833        0.0   0.607226 -0.009267  ...  4.857294 -0.830772  2.848661
#
# [325834 rows x 175 columns]

# %% [markdown]
# # **Removing unwanted rows and columns**

# %%
data.describe()
# Out:
#                label             f1  ...           f173           f174
# count  325834.000000  325834.000000  ...  325834.000000  325834.000000
# mean        4.062421     -15.143602  ...       0.764646       0.667567
# std         1.604617       3.504255  ...       0.273847       0.471260
# min         1.000000     -23.971000  ...       0.111110      -1.000000
# 25%         3.000000     -17.848000  ...       0.506170       0.357140
# 50%         4.000000     -15.992000  ...       1.000000       1.000000
# 75%         6.000000     -11.786000  ...       1.000000       1.000000
# max         7.000000       2.535600  ...       1.000000       1.000000
#
# [8 rows x 175 columns]

# %%
data.pop('f137')
# Out:
# 0         6711
# 1         6274
# 2         6215
# 3         6836
# 4         6682
#           ...
# 325829    5960
# 325830    7649
# 325831    6004
# 325832    6234
# 325833    7980
# Name: f137, Length: 325834, dtype: int64

# %%
data.pop('f138')
# Out:
# 0         6143
# 1         5084
# 2         5035
# 3         5745
# 4         5883
#           ...
# 325829    5510
# 325830    6544
# 325831    5343
# 325832    5469
# 325833    6950
# Name: f138, Length: 325834, dtype: int64

# %%
data.pop('f139')
# Out:
# 0         4570
# 1         3297
# 2         3033
# 3         4212
# 4         4434
#           ...
# 325829    3023
# 325830    4690
# 325831    3444
# 325832    3442
# 325833    5297
# Name: f139, Length: 325834, dtype: int64

# %%
data.pop('f140')
# Out:
# 0         5064
# 1         3777
# 2         3837
# 3         4534
# 4         4627
#           ...
# 325829    4711
# 325830    4823
# 325831    4255
# 325832    4472
# 325833    5004
# Name: f140, Length: 325834, dtype: int64

# %%
data.pop('f141')
# Out:
# 0         8212
# 1         8214
# 2         8588
# 3         7691
# 4         7072
#           ...
# 325829    9327
# 325830    7104
# 325831    8071
# 325832    6766
# 325833    6458
# Name: f141, Length: 325834, dtype: int64

# %%
data.pop('f30')
# Out:
# 0         44.369
# 1         44.992
# 2         45.466
# 3         46.654
# 4         46.828
#            ...
# 325829    63.745
# 325830    63.669
# 325831    60.734
# 325832    60.757
# 325833    60.623
# Name: f30, Length: 325834, dtype: float64

# %%
data.pop('f79')
# Out:
# 0         42.797
# 1         42.706
# 2         42.195
# 3         42.803
# 4         42.535
#            ...
# 325829    26.197
# 325830    25.437
# 325831    26.574
# 325832    27.211
# 325833    26.204
# Name: f79, Length: 325834, dtype: float64

# %%
data.pop('f105')
# Out:
# 0          7.6875
# 1          7.8378
# 2          6.4783
# 3          3.8378
# 4          3.8824
#            ...
# 325829     9.9677
# 325830     3.2174
# 325831    81.6000
# 325832    11.5830
# 325833     5.0889
# Name: f105, Length: 325834, dtype: float64

# %%
data.pop('f116')
# Out:
# 0         17.28
# 1         16.24
# 2         16.58
# 3         14.27
# 4         11.32
#           ...
# 325829    16.90
# 325830     9.16
# 325831    27.38
# 325832    14.73
# 325833    11.36
# Name: f116, Length: 325834, dtype: float64

# %%
data.pop('f121')
# Out:
# 0         22.667
# 1         18.556
# 2         19.000
# 3         17.333
# 4         16.667
#            ...
# 325829    22.222
# 325830    15.444
# 325831    23.111
# 325832    19.111
# 325833    14.667
# Name: f121, Length: 325834, dtype: float64

# %%
data.pop('f154')
# Out:
# 0         294110.0
# 1         412400.0
# 2         439570.0
# 3         296240.0
# 4         232610.0
#             ...
# 325829    423430.0
# 325830    222500.0
# 325831    354320.0
# 325832    216430.0
# 325833    150320.0
# Name: f154, Length: 325834, dtype: float64

# %%
data.pop('f156')
# Out:
# 0         2199.40
# 1         2338.40
# 2         3321.30
# 3         1748.10
# 4         1365.40
#            ...
# 325829    5811.10
# 325830    1460.90
# 325831    3239.50
# 325832    3867.20
# 325833     224.02
# Name: f156, Length: 325834, dtype: float64

# %%
data.pop('f157')
# Out:
# 0          92560.0
# 1         100280.0
# 2         128320.0
# 3          80640.0
# 4          69540.0
#             ...
# 325829    200760.0
# 325830     82140.0
# 325831    124620.0
# 325832    142880.0
# 325833     48540.0
# Name: f157, Length: 325834, dtype: float64

# %%
data.pop('f159')
# Out:
# 0         48.444
# 1         49.778
# 2         49.444
# 3         50.667
# 4         51.222
#            ...
# 325829    47.000
# 325830    49.667
# 325831    48.778
# 325832    51.556
# 325833    51.333
# Name: f159, Length: 325834, dtype: float64

# %% [markdown]
# # **Plotting Graphs**

# %%
data_1 = data.iloc[:,1:]
data_1
# Out:
#               f1       f2        f3  ...     f172     f173     f174
# 0      -13.55900 -21.4070 -11.40400  ...  1.67700  0.20988  0.65422
# 1      -12.80200 -20.3350 -10.39900  ...  0.84869  0.50617 -0.18898
# 2      -12.43100 -19.9020 -10.07400  ...  1.27300  0.30864  0.10483
# 3      -12.68900 -19.5290 -10.02800  ...  1.14910  0.38272  0.41603
# 4      -12.68600 -19.2780  -9.81850  ...  1.58110  0.20988  0.50000
# ...          ...      ...       ...  ...      ...      ...      ...
# 325829   2.48230  -7.6870   1.07950  ...  1.06090  0.35802  0.63246
# 325830   2.52340  -7.6745   1.08680  ...  2.19720  0.11111  0.81224
# 325831  -1.92700 -11.4160  -2.43540  ...  1.27300  0.30864  0.31623
# 325832   0.12483 -10.1440  -0.62193  ...  0.34883  0.80247  0.18898
# 325833   0.20063 -10.0500  -0.59892  ...  2.04320  0.13580  0.72732
#
# [325834 rows x 160 columns]

# %%
data_1.plot(kind='line')
plt.legend(())

# %%
data_1.plot(kind='line')
plt.legend(())
plt.title('Trend of the data',fontsize=20)
plt.xlabel('Instances',fontsize=20)
plt.ylabel('Attributes',fontsize=20)
plt.xticks([39165,42765,118437,192503,239621,324695,325834],
           [r'$1$',r'$2$',r'$3$',r'$4$',r'$5$',r'$6$',r'$7$'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f5a47f26190>,
# ...
#  [Text(0, 0, '$1$'),
#   Text(0, 0, '$2$'),
#   Text(0, 0, '$3$'),
#   Text(0, 0, '$4$'),
#   Text(0, 0, '$5$'),
#   Text(0, 0, '$6$'),
#   Text(0, 0, '$7$')])

# %%
z = np.arange(1303336)
data.plot.scatter(x=['f1','f3','f4','f5'],y=['f101','f102','f103','f104'],c=z)
plt.title("Plot between Polarimetric and Optical features", fontsize=20)
plt.xlabel('Polarimetric Features',fontsize=20)
plt.ylabel('Optical Features',fontsize=20)
# Out:
# Text(0, 0.5, 'Optical Features')

# %%
x = data.iloc[:,1:50]
y = data.iloc[:,99:148]
species = np.arange(15965866)
plt.figure()
plt.title('Plot between Polarimetric and Optical features')
plt.scatter(x,y, c=species)
plt.xlabel('Polarimetric Features')
plt.ylabel('Optical Features')
plt.show()

# %%
data_1.plot(kind='hist',color='red')
plt.legend(())
plt.xlim(-200,250)
plt.title('Frequency Distribution')
plt.xlabel('values',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x = data['f1']
y = data['f101']
plt.bar(x,y,color='k')
# Out:
# <BarContainer object of 325834 artists>

# %%
data_1.plot(kind='density')
plt.legend(())

# %%
data_1.plot(kind='kde')
plt.legend(())

# %% [markdown]
# # **Applying algorithm**

# %%
from sklearn import linear_model
linreg = linear_model.LinearRegression()

# %%
X = data.iloc[:,1:50]
X
# Out:
#               f1       f2        f3  ...       f48       f49      f50
# 0      -13.55900 -21.4070 -11.40400  ...  0.005980  0.024823 -12.5640
# 1      -12.80200 -20.3350 -10.39900  ...  0.005980  0.027797 -11.5590
# 2      -12.43100 -19.9020 -10.07400  ...  0.005980  0.029540 -11.0400
# 3      -12.68900 -19.5290 -10.02800  ...  0.005980  0.029684 -10.9100
# 4      -12.68600 -19.2780  -9.81850  ...  0.006601  0.030782 -10.5810
# ...          ...      ...       ...  ...       ...       ...      ...
# 325829   2.48230  -7.6870   1.07950  ...  0.025899  0.471100   2.5997
# 325830   2.52340  -7.6745   1.08680  ...  0.033612  0.519980   2.9641
# 325831  -1.92700 -11.4160  -2.43540  ...  0.007981  0.318630  -0.6705
# 325832   0.12483 -10.1440  -0.62193  ...  0.014835  0.371010   1.6408
# 325833   0.20063 -10.0500  -0.59892  ...  0.019257  0.410100   2.0701
#
# [325834 rows x 49 columns]

# %%
X.shape
# Out:
# (325834, 49)

# %%
Y = data.iloc[:,99:148]
Y
# Out:
#          f101   f102   f103     f104  ...      f155     f158     f160     f161
# 0       0.048  0.165  0.369  0.76978  ...  0.051277  1.10810  3.13580  0.57778
# 1       0.037  0.103  0.290  0.77370  ...  0.067854  1.14560  0.39506  0.46667
# 2       0.046  0.107  0.298  0.73256  ...  0.117030  1.26510  0.24691  0.61111
# 3       0.074  0.120  0.284  0.58659  ...  0.036817  1.07640  0.88889  0.61111
# 4       0.068  0.131  0.264  0.59036  ...  0.021300  1.04350  0.39506  0.56667
# ...       ...    ...    ...      ...  ...       ...      ...      ...      ...
# 325829  0.031  0.113  0.309  0.81765  ...  0.218260  1.55840  9.55560  0.36706
# 325830  0.069  0.117  0.222  0.52577  ...  0.013981  1.02840  2.22220  0.37094
# 325831  0.005  0.096  0.408  0.97579  ...  0.105340  1.23550  6.61730  0.34061
# 325832  0.024  0.107  0.278  0.84106  ...  0.130150  1.29920  0.24691  0.77778
# 325833  0.045  0.097  0.229  0.67153  ... -0.028444  0.94469  1.33330  0.49542
#
# ...

# %%
Y.shape
# Out:
# (325834, 49)

# %%
x_train = X[:-20]
y_train = Y[:-20]
x_test = X[-20:]
y_test = Y[-20:]

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linreg.coef_
# Out:
# array([[-4.29649999e-02, -2.17501227e-02,  6.75304944e-02, ...,
#         -1.24432890e+00,  3.92290954e+00,  1.02570416e-03],
#        [-4.20696863e-02,  7.02879563e-03,  1.05216380e-02, ...,
#         -2.36917301e+00,  4.29267107e+00,  5.96976005e-04],
#        [ 1.48622274e-01,  1.04168962e-01, -2.37262188e-01, ...,
#         -3.02517308e+00,  5.08928601e-01, -5.01278618e-03],
#        ...,
#        [ 4.15463257e-01,  8.00576658e-02, -3.93891169e-01, ...,
#         -5.03185151e+00,  1.14686643e+01,  4.31263988e-02],
#        [-6.58526501e+00,  1.86145217e+00,  2.13960854e+00, ...,
#          5.42559513e+01, -5.54972728e+00,  6.49254998e-02],
#        [ 6.73291793e-01,  1.71317882e-02, -4.93327522e-01, ...,
#         -7.78225532e+00, -4.52483886e+00, -1.83775893e-02]])

# %%
linreg.predict(x_test)
# Out:
# array([[ 4.14279604e-02,  1.66277291e-01,  5.21102968e-01,
#          8.51596824e-01,  2.45323398e+00,  6.97024600e-01,
#          7.59881412e-01,  6.67112711e-01,  3.46161129e-01,
#          7.65846566e-01,  7.61491627e-01,  5.07079430e-01,
#          3.13744997e+00, -4.43814287e-01,  6.56527153e-01,
#         -7.90585570e-02,  8.56968115e+00,  8.40069665e+00,
#          3.96982647e+00,  4.59628827e-01,  8.26146141e+00,
#          1.88388609e+00,  1.77489899e+00,  1.99208100e-01,
#          2.91896405e-01,  4.71011516e+00,  2.26649338e-01,
#          8.69024514e-01,  4.09964627e-01,  2.74477849e-01,
#          6.25961851e-01,  6.42774717e-01,  4.31925060e-01,
#          7.45440210e-01,  5.45426715e+00,  2.06179616e+00,
#         -2.59774309e+00,  1.17094491e+00,  1.11812771e+00,
#          3.57812534e-01,  4.91105305e-01,  1.00545356e+00,
#          5.07095723e-01,  2.86228983e+00,  5.07095723e-01,
#          3.38672428e-01,  1.98218923e+00,  1.65462795e+00,
# ...

# %%
y_test
# Out:
#          f101   f102   f103     f104  ...      f155     f158      f160      f161
# 325814  0.007  0.126  0.429  0.96789  ...  0.234180  1.61160   1.35800  0.444440
# 325815  0.001  0.094  0.364  0.99452  ...  0.210760  1.53410   0.98765  0.688890
# 325816  0.010  0.099  0.384  0.94924  ...  0.268550  1.73430   0.54321  0.511110
# 325817  0.010  0.098  0.379  0.94859  ...  0.262550  1.71210   1.77780  0.511110
# 325818  0.014  0.101  0.411  0.93412  ...  0.246170  1.65310   0.61728  0.611110
# 325819  0.009  0.095  0.336  0.94783  ...  0.172810  1.41780   1.43210  0.315380
# 325820  0.012  0.082  0.336  0.93103  ...  0.204200  1.51320   3.77780  0.448720
# 325821  0.017  0.140  0.412  0.92075  ...  0.239340  1.62930  13.13600  0.184650
# 325822  0.010  0.100  0.371  0.94751  ...  0.197790  1.49310   0.66667  0.544440
# 325823  0.009  0.106  0.375  0.95313  ...  0.216150  1.55150   0.98765  0.744440
# 325824  0.015  0.141  0.440  0.93407  ...  0.116130  1.26280  24.39500  0.087076
# ...

# %%
linreg.score(x_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:434: FutureWarning: The default value of multioutput (not exposed in score method) will change from 'variance_weighted' to 'uniform_average' in 0.23 to keep consistent with 'metrics.r2_score'. To specify the default value manually and avoid the warning, please either call 'metrics.r2_score' directly or make a custom scorer with 'metrics.make_scorer' (the built-in scorer 'r2' uses multioutput='uniform_average').
#   "multioutput='uniform_average').", FutureWarning)
# -3.4037373830404993

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import datasets

# %%
x_train = X[:-20]
y_train = Y[:-20]
x_test = X[-20:]
y_test = Y[-20:]
linreg = linear_model.LinearRegression()
linreg.fit(x_train,y_train)
y = linreg.predict(x_test)
plt.scatter(x_test,y_test,color='k')
plt.plot(x_test,y,color='r',linewidth=3)
